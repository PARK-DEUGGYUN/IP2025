# %% [markdown]
# # 1.5.3 Shi-Tomasi Corner Detector & Good Features to Track

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('The-Ankh.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
corners = cv2.goodFeaturesToTrack(gray,250,0.01,10)
corners = np.int0(corners)
for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),3,255,-1)
# Out:
# C:\Users\U209-5\AppData\Local\Temp\ipykernel_17296\3735693699.py:4: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)

# %%
plt.figure(figsize=(20,20))    
plt.imshow(img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x2bb68381070>, None)
